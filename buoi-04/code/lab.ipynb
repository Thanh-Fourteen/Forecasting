# %% [markdown]
# # Buổi 4 — Lab
#
# Chạy từng ô từ trên xuống. Mỗi bước ứng với một mục trong tài liệu (mục 5). Bạn sửa `bieu_do.py`; các ô tự dùng bản mới.

# %%
# sửa tệp .py trong code/ thì các ô sau tự dùng bản mới, không cần khởi động lại
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Bước 1 — Chạy code đầu buổi

# %%
# %matplotlib inline
import bieu_do as bd

df = bd.doc_luot_thue()
print(f"{len(df)} giờ trên lưới, thiếu {df['cnt'].isna().sum()}")
print(bd.ho_so_tuan(df).loc[:, [8, 13, 17]].round(0))

# %%
bd.bo_bieu_do_chan_doan(df);

# %% [markdown]
# ## Bước 2 — Sửa `ho_so_tuan`
#
# Sửa trong `bieu_do.py`, rồi chạy ô dưới: thứ Hai 8h phải ra 412, Chủ nhật 8h ra 84.

# %%
bd.ho_so_tuan(df).loc[:, [8, 13, 17]].round(0)

# %% [markdown]
# ## Bước 3 — Tám hàm vẽ, ghép `bo_bieu_do_chan_doan`
#
# Viết các hàm trong `bieu_do.py` (tài liệu mục 5, bước 3), rồi chạy ô dưới. Chấm: `python lab.py check` trong terminal.

# %%
fig = bd.bo_bieu_do_chan_doan(df)
print("các ô:", [ax.get_label() for ax in fig.axes if ax.get_label() and not ax.get_label().startswith("<")])

# %% [markdown]
# ## Bước 4 — Năm nhận xét có bằng chứng
#
# Viết vào ô này năm câu dạng "*[nhận xét]* — thấy ở *[hình]*, *[chỗ nào]*, *[con số]*".
#
# 1.
# 2.
# 3.
# 4.
# 5.

# %% [markdown]
# ## Bước 5 — Vẽ lại biểu đồ gây hiểu nhầm
#
# `bieu_do_gay_hieu_nham` dựng sẵn, không sửa. Viết `ve_lai_trung_thuc` trong `bieu_do.py`.

# %%
bd.bieu_do_gay_hieu_nham(df);

# %%
bd.ve_lai_trung_thuc(df);
